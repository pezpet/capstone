# %% [markdown]
# # WSL Merge
#
# Merge score data with date and time data

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Scores Data

# %%
df = pd.read_csv("../data/wsl/avg_scores_all_years.csv", index_col=0).rename(columns={'top_two_waves_total': 'score'})
df.head()
# Out:
#    year                      event    round     heat             name  score
# 0  2008  Quiksilver Pro Gold Coast  Round 2  Heat 1        Andy Irons  16.37
# 1  2008  Quiksilver Pro Gold Coast  Round 2  Heat 1    Tamaroa McComb   5.90
# 2  2008  Quiksilver Pro Gold Coast  Round 2  Heat 2     Julian Wilson  14.00
# 3  2008  Quiksilver Pro Gold Coast  Round 2  Heat 2   Pancho Sullivan  13.23
# 4  2008  Quiksilver Pro Gold Coast  Round 2  Heat 3     Jeremy Flores  10.83

# %% [markdown]
# Look at unique events and find total amoun of heats for the Pipeline events. Event names change with sponsorship changes.

# %%
df["event"].unique()
# Out:
# array(['Quiksilver Pro Gold Coast', 'Rip Curl Pro Bells Beach',
#        'Billabong Pro Teahupoo', 'Globe Pro Fiji', 'Billabong Pro J-Bay',
#        'Rip Curl Pro Search Bali', 'Boost Mobile Pro',
#        'Quiksilver Pro France', 'Billabong Pro Mundaka',
#        'Hang Loose Santa Catarina Pro', 'Billabong Pipeline Masters',
#        'Hurley Pro Trestles', 'Rip Curl Search', 'Santa Catarina Pro',
#        'Rip Curl Pro Portugal', 'Billabong Pipe Masters',
#        'Billabong Rio Pro', 'Quiksilver Pro New York', 'Volcom Fiji Pro',
#        "O'Neill Coldwater Classic Santa Cruz", 'Oakley Pro Bali',
#        'Drug Aware Margaret River Pro', 'Fiji Pro', 'J-Bay Open',
#        'Billabong Pro Tahiti', 'Hurley Pro at Trestles',
#        'Moche Rip Curl Pro Portugal', 'Oi Rio Pro',
#        'MEO Rip Curl Pro Portugal', 'Outerknown Fiji Pro',
#        'Corona Open J-Bay', 'Corona Bali Protected',
#        'Uluwatu CT Margaret River Pro', "Tahiti Pro Teahupo'o",
#        'Margaret River Pro',
#        'Billabong Pipe Masters presented by Hydro Flask',
#        'Rip Curl Newcastle Cup presented by Corona',
#        'Rip Curl Narrabeen Classic presented by Corona',
#        'Boost Mobile Margaret River Pro presented by Corona',
#        'Rip Curl Rottnest Search presented by Corona',
#        'Corona Open Mexico presented by Quiksilver',
#        'Billabong Pro Pipeline', 'Hurley Pro Sunset Beach',
#        'MEO Pro Portugal'], dtype=object)

# %% [markdown]
# Locate rows with pipeline events and get the shape of the resulting dataframe. This is the amount of heats in pipeline events with data.

# %%
# Make list of pipeline events from previous cell
pipe = [
    "Billabong Pipe Masters presented by Hydro Flask",
    "Billabong Pro Pipeline",
    "Billabong Pipe Masters presented by Hydro Flask",
    "Billabong Pipe Masters",
    "Billabong Pipeline Masters",
]

df.loc[df["event"].isin(pipe)].shape
# Out:
# (1649, 6)

# %% [markdown]
# Check all other events to confirm pipeline has the most data.

# %%
df["event"].value_counts().head(15)
# Out:
# Quiksilver Pro Gold Coast        1473
# Quiksilver Pro France            1444
# Rip Curl Pro Bells Beach         1422
# Billabong Pipe Masters           1176
# Billabong Pro Teahupoo            729
# Hurley Pro Trestles               614
# Oi Rio Pro                        574
# Billabong Pro J-Bay               493
# Hurley Pro at Trestles            472
# Billabong Pro Tahiti              472
# Billabong Rio Pro                 472
# Rip Curl Pro Portugal             472
# Drug Aware Margaret River Pro     471
# MEO Rip Curl Pro Portugal         456
# J-Bay Open                        354
# Name: event, dtype: int64

# %% [markdown]
# **Pipeline is the event with most data**
#
# Trestles is another good target with data and historical buoy info.

# %%
# Cast year data as string to avoid groupby issues
df["year"] = df["year"].astype(str)

# %% [markdown]
# ### Check and rename rounds and heats for consistency accross events
#
# I've mapped these manually but str methods would reduce the amount of code

# %%
# Get unique round names
df["round"].unique()
# Out:
# array(['Round 2', 'Round 1', 'Round 3', 'Round 4', 'Quarterfinal',
#        'Semifinal', 'Final', 'Round 5', 'Quarterfinals', 'Semifinals',
#        'Trials Quarterfinals', 'Trials Round 1', 'Trials Semifinals',
#        'Trials Final', 'Elimination Round', 'Seeding Round',
#        'Round of 32', 'Round of 16', 'Opening Round'], dtype=object)

# %%
# Map round names to a consistent standard
# Round 1, 2, 3, 4 and 5, then Quarterfinals, Semifinals and Final. Idem for trials
df["round"] = df["round"].map(
    {
        "Seeding Round": "Round 1",
        "Round of 32": "Round 3",
        "Quarterfinal": "Quarterfinals",
        "Round of 16": "Round 4",
        "Elimination Round": "Round 2",
        "Opening Round": "Round 1",
        "Round 1": "Round 1",
        "Round 2": "Round 2",
        "Round 3": "Round 3",
        "Round 4": "Round 4",
        "Round 5": "Round 5",
        "Quarterfinals": "Quarterfinals",
        "Final": "Final",
        "Semifinal": "Semifinals",
        "Semifinals": "Semifinals",
        "Trials Quarterfinals": "Trials Quarterfinals",
        "Trials Round 1": "Trials Round 1",
        "Trials Semifinals": "Trials Semifinals",
        "Trials Final": "Trials Final",
    }
)

# %%
# Get unique heat names
df['heat'].unique()
# Out:
# array(['Heat 1 ', 'Heat 2 ', 'Heat 3 ', 'Heat 4 ', 'Heat 5 ', 'Heat 6 ',
#        'Heat 7 ', 'Heat 8 ', 'Heat 9 ', 'Heat 10 ', 'Heat 11 ',
#        'Heat 12 ', 'Heat 13 ', 'Heat 14 ', 'Heat 15 ', 'Heat 16 ',
#        'Heat 8 Watch replay', 'Heat 6 Watch replay',
#        'Heat 2 Watch replay', 'Heat 1 Watch replay',
#        'Heat 4 Watch replay', 'Heat 10 Watch replay',
#        'Heat 11 Watch replay', 'Heat 12 Watch replay',
#        'Heat 3 Watch replay', 'Heat 5 Watch replay',
#        'Heat 7 Watch replay', 'Heat 9 Watch replay',
#        'Heat 13 Watch replay', 'Heat 14 Watch replay',
#        'Heat 15 Watch replay', 'Heat 16 Watch replay'], dtype=object)

# %%
# Map for consistency and to eliminate 'Watch replay' strings from webscraping
df["heat"] = df["heat"].map(
    {
        "Heat 1 ": "Heat 1",
        "Heat 2 ": "Heat 2",
        "Heat 3 ": "Heat 3",
        "Heat 4 ": "Heat 4",
        "Heat 5 ": "Heat 5",
        "Heat 6 ": "Heat 6",
        "Heat 7 ": "Heat 7",
        "Heat 8 ": "Heat 8",
        "Heat 9 ": "Heat 9",
        "Heat 10 ": "Heat 10",
        "Heat 11 ": "Heat 11",
        "Heat 12 ": "Heat 12",
        "Heat 13 ": "Heat 13",
        "Heat 14 ": "Heat 14",
        "Heat 15 ": "Heat 15",
        "Heat 16 ": "Heat 16",
        "Heat 8 Watch replay": "Heat 8",
        "Heat 6 Watch replay": "Heat 6",
        "Heat 2 Watch replay": "Heat 2",
        "Heat 1 Watch replay": "Heat 1",
        "Heat 4 Watch replay": "Heat 4",
        "Heat 10 Watch replay": "Heat 10",
        "Heat 11 Watch replay": "Heat 11",
        "Heat 12 Watch replay": "Heat 12",
        "Heat 3 Watch replay": "Heat 3",
        "Heat 5 Watch replay": "Heat 5",
        "Heat 7 Watch replay": "Heat 7",
        "Heat 9 Watch replay": "Heat 9",
        "Heat 13 Watch replay": "Heat 13",
        "Heat 14 Watch replay": "Heat 14",
        "Heat 15 Watch replay": "Heat 15",
        "Heat 16 Watch replay": "Heat 16",
    }
)

# %% [markdown]
# ## Focus on Pipeline data
#
# **Reindex doesn't work as expected**

# %%
# Get only pipeline scores
# Uses 'pipe' list from earlier
df_pipe = df.loc[df["event"].isin(pipe)].reindex()
df_pipe
# Out:
#      year                       event       round    heat               name  \
# 0    2008  Billabong Pipeline Masters     Round 2  Heat 1  Kamalei Alexander
# 1    2008  Billabong Pipeline Masters     Round 2  Heat 1       Mikael Picon
# 2    2008  Billabong Pipeline Masters     Round 2  Heat 2       Evan Valiere
# 3    2008  Billabong Pipeline Masters     Round 2  Heat 2      Mick Campbell
# 4    2008  Billabong Pipeline Masters     Round 2  Heat 3      Jamie O'Brien
# ..    ...                         ...         ...     ...                ...
# 105  2022      Billabong Pro Pipeline  Semifinals  Heat 1        Miguel Pupo
# 106  2022      Billabong Pro Pipeline  Semifinals  Heat 2         Seth Moniz
# 107  2022      Billabong Pro Pipeline  Semifinals  Heat 2        Caio Ibelli
# 108  2022      Billabong Pro Pipeline       Final  Heat 1       Kelly Slater
# 109  2022      Billabong Pro Pipeline       Final  Heat 1         Seth Moniz
#
#      score
# 0    11.90
# 1    11.67
# 2    14.57
# 3    14.34
# 4    15.00
# ..     ...
# 105   9.50
# 106  13.50
# 107   6.33
# 108  18.77
# 109  12.53
#
# [1649 rows x 6 columns]

# %% [markdown]
# ## Load event dates data
#
# This data was scraped idependently from scores to avoid using selenium

# %%
# Pipeline heat dates scraped from /results endpoint instead of main
event_dates = pd.read_csv("../data/wsl/pipe_masters_heat_dates.csv", index_col=0)
event_dates.head()
# Out:
#    year                       event    round    heat date
# 0  2008  Billabong Pipeline Masters  Round 1  Heat 1
# 1  2008  Billabong Pipeline Masters  Round 1  Heat 2
# 2  2008  Billabong Pipeline Masters  Round 1  Heat 3
# 3  2008  Billabong Pipeline Masters  Round 1  Heat 4
# 4  2008  Billabong Pipeline Masters  Round 1  Heat 5

# %% [markdown]
# ### Missing data
#
# Events before 2014 have no heat dates. Have contacted WSL to inquire about getting this data in a structured way.
#
# Other option would be to investigate news articles manually but I'll do that if I have time after project is completed

# %%
event_dates["date"].value_counts()
# Out:
#                       330
#  December 19, 2014     27
#  February 1, 2022      24
#  December 16, 2018     24
#  December 17, 2017     24
#  December 18, 2016     23
#  December 17, 2020     22
#  December 16, 2015     19
#  January 29, 2022      16
#  December 11, 2019     16
#  December 19, 2016     16
#  December 10, 2019     16
#  December 12, 2018     15
#  December 19, 2019     15
#  December 18, 2017     15
#  December 12, 2014     12
#  December 13, 2018     12
#  December 14, 2016     12
#  December 9, 2020      12
#  December 11, 2015     12
#  December 20, 2020     12
#  December 10, 2015     12
#  December 13, 2014     12
#  December 17, 2018     11
#  December 11, 2017      9
#  December 17, 2015      8
#  February 5, 2022       7
#  December 16, 2017      3
#  December 14, 2020      1
# Name: date, dtype: int64

# %%
# Sanity check
event_dates[event_dates["year"] == 2022]["round"].value_counts()
# Out:
# Round of 32          16
# Opening Round        12
# Round of 16           8
# Elimination Round     4
# Quarterfinals         4
# Semifinals            2
# Final                 1
# Name: round, dtype: int64

# %% [markdown]
# ### Round and heat names have to be mapped like score data

# %%
event_dates["round"].unique()
# Out:
# array(['Round 1', 'Round 2', 'Round 3', 'Round 4', 'Quarterfinal',
#        'Semifinal', 'Final', 'Round 5', 'Quarterfinals', 'Semifinals',
#        'Trials Round 1', 'Trials Quarterfinals', 'Trials Semifinals',
#        'Trials Final', 'Seeding Round', 'Elimination Round',
#        'Round of 32', 'Round of 16', 'Opening Round'], dtype=object)

# %%
df_pipe["round"].unique()
# Out:
# array(['Round 2', 'Round 1', 'Round 3', 'Round 4', 'Quarterfinals',
#        'Semifinals', 'Final', 'Round 5', 'Trials Quarterfinals',
#        'Trials Round 1', 'Trials Semifinals', 'Trials Final'],
#       dtype=object)

# %%
event_dates["round"] = event_dates["round"].map(
    {
        "Seeding Round": "Round 1",
        "Round of 32": "Round 3",
        "Quarterfinal": "Quarterfinals",
        "Round of 16": "Round 4",
        "Elimination Round": "Round 2",
        "Opening Round": "Round 1",
        "Round 1": "Round 1",
        "Round 2": "Round 2",
        "Round 3": "Round 3",
        "Round 4": "Round 4",
        "Round 5": "Round 5",
        "Quarterfinals": "Quarterfinals",
        "Final": "Final",
        "Semifinal": "Semifinals",
        "Semifinals": "Semifinals",
        "Trials Quarterfinals": "Trials Quarterfinals",
        "Trials Round 1": "Trials Round 1",
        "Trials Semifinals": "Trials Semifinals",
        "Trials Final": "Trials Final",
    }
)

# %%
event_dates["heat"].unique()
# Out:
# array(['Heat 1', 'Heat 2', 'Heat 3', 'Heat 4', 'Heat 5', 'Heat 6',
#        'Heat 7', 'Heat 8', 'Heat 9', 'Heat 10', 'Heat 11', 'Heat 12',
#        'Heat 13', 'Heat 14', 'Heat 15', 'Heat 16'], dtype=object)

# %%
df_pipe["heat"].unique()
# Out:
# array(['Heat 1', 'Heat 2', 'Heat 3', 'Heat 4', 'Heat 5', 'Heat 6',
#        'Heat 7', 'Heat 8', 'Heat 9', 'Heat 10', 'Heat 11', 'Heat 12',
#        'Heat 13', 'Heat 14', 'Heat 15', 'Heat 16'], dtype=object)

# %%
df_pipe["heat"].unique() == event_dates["heat"].unique()
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True])

# %%
df_pipe["round"].unique() == event_dates["round"].unique()
# Out:
# array([False, False,  True,  True,  True,  True,  True,  True, False,
#        False,  True,  True])

# %% [markdown]
# ### Convert dates to datetime

# %%
# Check unique values
event_dates["date"].unique()
# Out:
# array([' ', ' December 12, 2014', ' December 13, 2014',
#        ' December 19, 2014', ' December 10, 2015', ' December 11, 2015',
#        ' December 16, 2015', ' December 17, 2015', ' December 14, 2016',
#        ' December 18, 2016', ' December 19, 2016', ' December 11, 2017',
#        ' December 16, 2017', ' December 17, 2017', ' December 18, 2017',
#        ' December 12, 2018', ' December 13, 2018', ' December 16, 2018',
#        ' December 17, 2018', ' December 10, 2019', ' December 11, 2019',
#        ' December 19, 2019', ' December 9, 2020', ' December 14, 2020',
#        ' December 17, 2020', ' December 20, 2020', ' January 29, 2022',
#        ' February 1, 2022', ' February 5, 2022'], dtype=object)

# %%
# Eliminate first character blank space
event_dates["date"] = event_dates["date"].str[1:]

# %% [markdown]
# Keep only rows with date data

# %%
event_dates = event_dates[event_dates["date"] != ""]

# %%
event_dates["date"] = pd.to_datetime(event_dates["date"])
event_dates["date"].unique()
# Out:
# array(['2014-12-12T00:00:00.000000000', '2014-12-13T00:00:00.000000000',
#        '2014-12-19T00:00:00.000000000', '2015-12-10T00:00:00.000000000',
#        '2015-12-11T00:00:00.000000000', '2015-12-16T00:00:00.000000000',
#        '2015-12-17T00:00:00.000000000', '2016-12-14T00:00:00.000000000',
#        '2016-12-18T00:00:00.000000000', '2016-12-19T00:00:00.000000000',
#        '2017-12-11T00:00:00.000000000', '2017-12-16T00:00:00.000000000',
#        '2017-12-17T00:00:00.000000000', '2017-12-18T00:00:00.000000000',
#        '2018-12-12T00:00:00.000000000', '2018-12-13T00:00:00.000000000',
#        '2018-12-16T00:00:00.000000000', '2018-12-17T00:00:00.000000000',
#        '2019-12-10T00:00:00.000000000', '2019-12-11T00:00:00.000000000',
#        '2019-12-19T00:00:00.000000000', '2020-12-09T00:00:00.000000000',
#        '2020-12-14T00:00:00.000000000', '2020-12-17T00:00:00.000000000',
#        '2020-12-20T00:00:00.000000000', '2022-01-29T00:00:00.000000000',
#        '2022-02-01T00:00:00.000000000', '2022-02-05T00:00:00.000000000'],
#       dtype='datetime64[ns]')

# %% [markdown]
# Save to csv and assign offsets in Excel

# %%
event_dates.to_csv("../data/wsl/pipeline_dates.csv")

# %% [markdown]
# Read in excel with offsets. This could be accomplished with a .apply function

# %%
event_dates_offset = pd.read_csv("../data/wsl/pipeline_dates_offset.csv", index_col=0)
# Convert date column to datetime format
event_dates_offset["date"] = pd.to_datetime(event_dates_offset["date"])
event_dates_offset['year'] = event_dates_offset['year'].astype(str)
event_dates_offset.head()
# Out:
#    year                   event    round    heat       date  hour
# 0  2014  Billabong Pipe Masters  Round 1  Heat 1 2014-12-12   6.0
# 1  2014  Billabong Pipe Masters  Round 1  Heat 2 2014-12-12   6.5
# 2  2014  Billabong Pipe Masters  Round 1  Heat 3 2014-12-12   7.0
# 3  2014  Billabong Pipe Masters  Round 1  Heat 4 2014-12-12   7.5
# 4  2014  Billabong Pipe Masters  Round 1  Heat 5 2014-12-12   8.0

# %% [markdown]
# ### Assign estimated times to heats based on dates and 30 minute heat times

# %%
# With help from
# https://www.codegrepper.com/code-examples/python/how+to+add+30+minutes+in+datetime+column+in+pandas
event_dates_offset["est_datetime"] = event_dates_offset.apply(
    lambda x: x["date"] + pd.DateOffset(hours=x["hour"]),
    axis=1,
)

# %%
event_dates_offset.head()
# Out:
#    year                   event    round    heat       date  hour  \
# 0  2014  Billabong Pipe Masters  Round 1  Heat 1 2014-12-12   6.0
# 1  2014  Billabong Pipe Masters  Round 1  Heat 2 2014-12-12   6.5
# 2  2014  Billabong Pipe Masters  Round 1  Heat 3 2014-12-12   7.0
# 3  2014  Billabong Pipe Masters  Round 1  Heat 4 2014-12-12   7.5
# 4  2014  Billabong Pipe Masters  Round 1  Heat 5 2014-12-12   8.0
#
#          est_datetime
# 0 2014-12-12 06:00:00
# 1 2014-12-12 06:30:00
# 2 2014-12-12 07:00:00
# 3 2014-12-12 07:30:00
# 4 2014-12-12 08:00:00

# %%
event_dates_offset.tail()
# Out:
#     year                   event          round    heat       date  hour  \
# 42  2022  Billabong Pro Pipeline  Quarterfinals  Heat 3 2022-02-05   7.0
# 43  2022  Billabong Pro Pipeline  Quarterfinals  Heat 4 2022-02-05   7.5
# 44  2022  Billabong Pro Pipeline     Semifinals  Heat 1 2022-02-05   8.0
# 45  2022  Billabong Pro Pipeline     Semifinals  Heat 2 2022-02-05   8.5
# 46  2022  Billabong Pro Pipeline          Final  Heat 1 2022-02-05   9.0
#
#           est_datetime
# 42 2022-02-05 07:00:00
# 43 2022-02-05 07:30:00
# 44 2022-02-05 08:00:00
# 45 2022-02-05 08:30:00
# 46 2022-02-05 09:00:00

# %% [markdown]
# ## Merge scores with times

# %%
scores_and_times = df_pipe.merge(
    event_dates_offset,
    left_on=["year", "event", "round", "heat"],
    right_on=["year", "event", "round", "heat"],
).drop(columns=["date", "hour"])
scores_and_times.head(30)
# Out:
#     year                   event    round     heat                  name  \
# 0   2014  Billabong Pipe Masters  Round 2   Heat 1          Kelly Slater
# 1   2014  Billabong Pipe Masters  Round 2   Heat 1         Reef McIntosh
# 2   2014  Billabong Pipe Masters  Round 2   Heat 2         Michel Bourez
# 3   2014  Billabong Pipe Masters  Round 2   Heat 2        Makai McNamara
# 4   2014  Billabong Pipe Masters  Round 2   Heat 3           Dusty Payne
# 5   2014  Billabong Pipe Masters  Round 2   Heat 3           Jordy Smith
# 6   2014  Billabong Pipe Masters  Round 2   Heat 4             Nat Young
# 7   2014  Billabong Pipe Masters  Round 2   Heat 4        Mitch Coleborn
# 8   2014  Billabong Pipe Masters  Round 2   Heat 5           Miguel Pupo
# 9   2014  Billabong Pipe Masters  Round 2   Heat 5        Raoni Monteiro
# 10  2014  Billabong Pipe Masters  Round 2   Heat 6         Filipe Toledo
# 11  2014  Billabong Pipe Masters  Round 2   Heat 6            Glenn Hall
# 12  2014  Billabong Pipe Masters  Round 2   Heat 7         Adrian Buchan
# 13  2014  Billabong Pipe Masters  Round 2   Heat 7          Travis Logie
# 14  2014  Billabong Pipe Masters  Round 2   Heat 8             Kai Otton
# 15  2014  Billabong Pipe Masters  Round 2   Heat 8         Brett Simpson
# 16  2014  Billabong Pipe Masters  Round 2   Heat 9  Freddy Patacchia Jr.
# 17  2014  Billabong Pipe Masters  Round 2   Heat 9           Mitch Crews
# 18  2014  Billabong Pipe Masters  Round 2  Heat 10          Jadson Andre
# 19  2014  Billabong Pipe Masters  Round 2  Heat 10           Tiago Pires
# 20  2014  Billabong Pipe Masters  Round 2  Heat 11         Julian Wilson
# 21  2014  Billabong Pipe Masters  Round 2  Heat 11         Dion Atkinson
# 22  2014  Billabong Pipe Masters  Round 2  Heat 12        Matt Wilkinson
# 23  2014  Billabong Pipe Masters  Round 2  Heat 12        Aritz Aranburu
# 24  2014  Billabong Pipe Masters  Round 1   Heat 1        Joel Parkinson
# 25  2014  Billabong Pipe Masters  Round 1   Heat 1            Glenn Hall
# 26  2014  Billabong Pipe Masters  Round 1   Heat 1         Julian Wilson
# 27  2014  Billabong Pipe Masters  Round 1   Heat 2       Sebastian Zietz
# 28  2014  Billabong Pipe Masters  Round 1   Heat 2        Raoni Monteiro
# 29  2014  Billabong Pipe Masters  Round 1   Heat 2         Michel Bourez
#
#     score        est_datetime
# 0   14.10 2014-12-13 06:00:00
# 1    7.00 2014-12-13 06:00:00
# 2    8.33 2014-12-13 06:30:00
# 3    4.57 2014-12-13 06:30:00
# 4    4.30 2014-12-13 07:00:00
# 5    4.30 2014-12-13 07:00:00
# 6    8.50 2014-12-13 07:30:00
# 7    4.77 2014-12-13 07:30:00
# 8    7.17 2014-12-13 08:00:00
# 9    4.13 2014-12-13 08:00:00
# 10   7.64 2014-12-13 08:30:00
# 11   7.07 2014-12-13 08:30:00
# 12   3.47 2014-12-13 09:00:00
# 13   1.30 2014-12-13 09:00:00
# 14   7.16 2014-12-13 09:30:00
# 15   6.83 2014-12-13 09:30:00
# 16   6.90 2014-12-13 10:00:00
# 17   1.57 2014-12-13 10:00:00
# 18   5.76 2014-12-13 10:30:00
# 19   2.73 2014-12-13 10:30:00
# 20   4.50 2014-12-13 11:00:00
# 21   0.84 2014-12-13 11:00:00
# 22   4.13 2014-12-13 11:30:00
# 23   3.24 2014-12-13 11:30:00
# 24  13.83 2014-12-12 06:00:00
# 25   4.26 2014-12-12 06:00:00
# 26   1.23 2014-12-12 06:00:00
# 27  14.13 2014-12-12 06:30:00
# 28   4.77 2014-12-12 06:30:00
# 29   2.90 2014-12-12 06:30:00

# %%
scores_cleaned_merged = pd.DataFrame(scores_and_times.groupby(by=['est_datetime']).mean())
scores_cleaned_merged
# Out:
#                          score
# est_datetime
# 2014-12-12 06:00:00   6.440000
# 2014-12-12 06:30:00   7.266667
# 2014-12-12 07:00:00   7.223333
# 2014-12-12 07:30:00  15.180000
# 2014-12-12 08:00:00   4.786667
# ...                        ...
# 2022-02-05 07:00:00  17.300000
# 2022-02-05 07:30:00   6.700000
# 2022-02-05 08:00:00   9.630000
# 2022-02-05 08:30:00   9.915000
# 2022-02-05 09:00:00  15.650000
#
# [407 rows x 1 columns]

# %% [markdown]
# ## Save scores and times to csv

# %%
scores_cleaned_merged.to_csv('../data/wsl/pipe_2014_2022_clean_dated.csv')

# %% [markdown]
# ## Get buoy data, wind data; and merge with scores and times

# %%
noaa = pd.read_csv('../data/noaa/pipeline_buoy_full_shifted.csv', index_col=0, parse_dates=True)
noaa
# Out:
#                      wave_height  dominant_period  avg_period  \
# date
# 2014-01-01 00:00:00         1.48            11.11        7.91
# 2014-01-01 00:30:00         1.53            11.76        8.05
# 2014-01-01 01:30:00         1.57            10.53        7.89
# 2014-01-01 02:00:00         1.51            11.76        7.85
# 2014-01-01 02:30:00         1.43             8.33        7.54
# ...                          ...              ...         ...
# 2022-03-10 04:30:00         1.20            12.00        7.70
# 2022-03-10 05:00:00         1.20            12.00        7.40
# 2022-03-10 05:30:00         1.30             9.00        7.50
# 2022-03-10 06:00:00         1.10            11.00        7.00
# 2022-03-10 06:30:00         1.10             9.00        7.10
#
#                      dominant_wave_direction_sin  dominant_wave_direction_cos  \
# date
# 2014-01-01 00:00:00                    -0.656059                     0.754710
# 2014-01-01 00:30:00                    -0.656059                     0.754710
# 2014-01-01 01:30:00                    -0.573576                     0.819152
# 2014-01-01 02:00:00                    -0.573576                     0.819152
# 2014-01-01 02:30:00                    -0.121869                     0.992546
# ...                                          ...                          ...
# 2022-03-10 04:30:00                    -0.292372                     0.956305
# 2022-03-10 05:00:00                    -0.515038                     0.857167
# 2022-03-10 05:30:00                     0.224951                     0.974370
# 2022-03-10 06:00:00                    -0.173648                     0.984808
# 2022-03-10 06:30:00                     0.190809                     0.981627
#
#                      wave_height_1.0_h  dominant_period_1.0_h  \
# date
# 2014-01-01 00:00:00                NaN                    NaN
# 2014-01-01 00:30:00                NaN                    NaN
# 2014-01-01 01:30:00               1.48                  11.11
# 2014-01-01 02:00:00               1.53                  11.76
# 2014-01-01 02:30:00               1.57                  10.53
# ...                                ...                    ...
# 2022-03-10 04:30:00               1.20                   9.00
# 2022-03-10 05:00:00               1.20                  11.00
# 2022-03-10 05:30:00               1.20                  12.00
# 2022-03-10 06:00:00               1.20                  12.00
# 2022-03-10 06:30:00               1.30                   9.00
#
#                      avg_period_1.0_h  dominant_wave_direction_sin_1.0_h  \
# date
# 2014-01-01 00:00:00               NaN                                NaN
# 2014-01-01 00:30:00               NaN                                NaN
# 2014-01-01 01:30:00              7.91                          -0.656059
# 2014-01-01 02:00:00              8.05                          -0.656059
# 2014-01-01 02:30:00              7.89                          -0.573576
# ...                               ...                                ...
# 2022-03-10 04:30:00              7.00                           0.000000
# 2022-03-10 05:00:00              7.10                          -0.292372
# 2022-03-10 05:30:00              7.70                          -0.292372
# 2022-03-10 06:00:00              7.40                          -0.515038
# 2022-03-10 06:30:00              7.50                           0.224951
#
#                      dominant_wave_direction_cos_1.0_h  ...  \
# date                                                    ...
# 2014-01-01 00:00:00                                NaN  ...
# 2014-01-01 00:30:00                                NaN  ...
# 2014-01-01 01:30:00                           0.754710  ...
# 2014-01-01 02:00:00                           0.754710  ...
# 2014-01-01 02:30:00                           0.819152  ...
# ...                                                ...  ...
# 2022-03-10 04:30:00                           1.000000  ...
# 2022-03-10 05:00:00                           0.956305  ...
# 2022-03-10 05:30:00                           0.956305  ...
# 2022-03-10 06:00:00                           0.857167  ...
# 2022-03-10 06:30:00                           0.974370  ...
#
#                      wave_height_6.0_h  dominant_period_6.0_h  \
# date
# 2014-01-01 00:00:00                NaN                    NaN
# 2014-01-01 00:30:00                NaN                    NaN
# 2014-01-01 01:30:00                NaN                    NaN
# 2014-01-01 02:00:00                NaN                    NaN
# 2014-01-01 02:30:00                NaN                    NaN
# ...                                ...                    ...
# 2022-03-10 04:30:00                1.2                   13.0
# 2022-03-10 05:00:00                1.3                   11.0
# 2022-03-10 05:30:00                1.3                   13.0
# 2022-03-10 06:00:00                1.2                   12.0
# 2022-03-10 06:30:00                1.3                   11.0
#
#                      avg_period_6.0_h  dominant_wave_direction_sin_6.0_h  \
# date
# 2014-01-01 00:00:00               NaN                                NaN
# 2014-01-01 00:30:00               NaN                                NaN
# 2014-01-01 01:30:00               NaN                                NaN
# 2014-01-01 02:00:00               NaN                                NaN
# 2014-01-01 02:30:00               NaN                                NaN
# ...                               ...                                ...
# 2022-03-10 04:30:00               7.9                          -0.406737
# 2022-03-10 05:00:00               8.1                          -0.358368
# 2022-03-10 05:30:00               7.9                          -0.515038
# 2022-03-10 06:00:00               7.6                          -0.309017
# 2022-03-10 06:30:00               7.5                          -0.342020
#
#                      dominant_wave_direction_cos_6.0_h  wave_height_9.0_h  \
# date
# 2014-01-01 00:00:00                                NaN                NaN
# 2014-01-01 00:30:00                                NaN                NaN
# 2014-01-01 01:30:00                                NaN                NaN
# 2014-01-01 02:00:00                                NaN                NaN
# 2014-01-01 02:30:00                                NaN                NaN
# ...                                                ...                ...
# 2022-03-10 04:30:00                           0.913545                1.4
# 2022-03-10 05:00:00                           0.933580                1.5
# 2022-03-10 05:30:00                           0.857167                1.5
# 2022-03-10 06:00:00                           0.951057                1.4
# 2022-03-10 06:30:00                           0.939693                1.3
#
#                      dominant_period_9.0_h  avg_period_9.0_h  \
# date
# 2014-01-01 00:00:00                    NaN               NaN
# 2014-01-01 00:30:00                    NaN               NaN
# 2014-01-01 01:30:00                    NaN               NaN
# 2014-01-01 02:00:00                    NaN               NaN
# 2014-01-01 02:30:00                    NaN               NaN
# ...                                    ...               ...
# 2022-03-10 04:30:00                   12.0               8.1
# 2022-03-10 05:00:00                   13.0               8.5
# 2022-03-10 05:30:00                   10.0               8.1
# 2022-03-10 06:00:00                   13.0               8.2
# 2022-03-10 06:30:00                   13.0               8.2
#
#                      dominant_wave_direction_sin_9.0_h  \
# date
# 2014-01-01 00:00:00                                NaN
# 2014-01-01 00:30:00                                NaN
# 2014-01-01 01:30:00                                NaN
# 2014-01-01 02:00:00                                NaN
# 2014-01-01 02:30:00                                NaN
# ...                                                ...
# 2022-03-10 04:30:00                          -0.469472
# 2022-03-10 05:00:00                          -0.422618
# 2022-03-10 05:30:00                           0.034899
# 2022-03-10 06:00:00                          -0.469472
# 2022-03-10 06:30:00                          -0.453990
#
#                      dominant_wave_direction_cos_9.0_h
# date
# 2014-01-01 00:00:00                                NaN
# 2014-01-01 00:30:00                                NaN
# 2014-01-01 01:30:00                                NaN
# 2014-01-01 02:00:00                                NaN
# 2014-01-01 02:30:00                                NaN
# ...                                                ...
# 2022-03-10 04:30:00                           0.882948
# 2022-03-10 05:00:00                           0.906308
# 2022-03-10 05:30:00                           0.999391
# 2022-03-10 06:00:00                           0.882948
# 2022-03-10 06:30:00                           0.891007
#
# [106152 rows x 30 columns]

# %%
wind = pd.read_csv('../data/wind/oahu_wind.csv', index_col=0, parse_dates=True)
wind
# Out:
#                      wind_speed  gust_speed  wind_direction_sin  \
# date
# 2014-01-01 00:00:00        0.28        0.78            0.907777
# 2014-01-01 00:30:00        0.18        0.44            0.866025
# 2014-01-01 01:00:00        0.26        0.58            0.866025
# 2014-01-01 01:30:00        0.06        0.34            0.999701
# 2014-01-01 02:00:00        0.28        0.54            0.819152
# ...                         ...         ...                 ...
# 2022-03-10 05:30:00        0.30        0.30            0.615661
# 2022-03-10 06:00:00        0.10        0.70            0.104528
# 2022-03-10 06:30:00        0.20        0.60            0.994522
# 2022-03-10 07:00:00        0.40        0.90            0.529919
# 2022-03-10 07:30:00        0.50        1.00           -0.500000
#
#                      wind_direction_cos
# date
# 2014-01-01 00:00:00           -0.419452
# 2014-01-01 00:30:00           -0.500000
# 2014-01-01 01:00:00           -0.500000
# 2014-01-01 01:30:00           -0.024432
# 2014-01-01 02:00:00            0.573576
# ...                                 ...
# 2022-03-10 05:30:00            0.788011
# 2022-03-10 06:00:00            0.994522
# 2022-03-10 06:30:00            0.104528
# 2022-03-10 07:00:00           -0.848048
# 2022-03-10 07:30:00            0.866025
#
# [143536 rows x 4 columns]

# %%
data = noaa.merge(
    scores_cleaned_merged.merge(wind, how="left", left_index=True, right_index=True),
    left_index=True,
    right_index=True,
)
data.head()
# Out:
#                      wave_height  dominant_period  avg_period  \
# 2014-12-12 06:00:00         2.56            11.76        9.82
# 2014-12-12 06:30:00         2.46            13.33        9.98
# 2014-12-12 07:00:00         2.20            12.50        9.79
# 2014-12-12 07:30:00         2.33            11.76        9.75
# 2014-12-12 08:00:00         2.48            11.76       10.13
#
#                      dominant_wave_direction_sin  dominant_wave_direction_cos  \
# 2014-12-12 06:00:00                    -0.681998                     0.731354
# 2014-12-12 06:30:00                    -0.681998                     0.731354
# 2014-12-12 07:00:00                    -0.681998                     0.731354
# 2014-12-12 07:30:00                    -0.681998                     0.731354
# 2014-12-12 08:00:00                    -0.529919                     0.848048
#
#                      wave_height_1.0_h  dominant_period_1.0_h  \
# 2014-12-12 06:00:00               2.52                  13.33
# 2014-12-12 06:30:00               2.40                  13.33
# 2014-12-12 07:00:00               2.56                  11.76
# 2014-12-12 07:30:00               2.46                  13.33
# 2014-12-12 08:00:00               2.20                  12.50
#
#                      avg_period_1.0_h  dominant_wave_direction_sin_1.0_h  \
# 2014-12-12 06:00:00              9.60                          -0.669131
# 2014-12-12 06:30:00              9.99                          -0.669131
# 2014-12-12 07:00:00              9.82                          -0.681998
# 2014-12-12 07:30:00              9.98                          -0.681998
# 2014-12-12 08:00:00              9.79                          -0.681998
#
#                      dominant_wave_direction_cos_1.0_h  ...  \
# 2014-12-12 06:00:00                           0.743145  ...
# 2014-12-12 06:30:00                           0.743145  ...
# 2014-12-12 07:00:00                           0.731354  ...
# 2014-12-12 07:30:00                           0.731354  ...
# 2014-12-12 08:00:00                           0.731354  ...
#
#                      wave_height_9.0_h  dominant_period_9.0_h  \
# 2014-12-12 06:00:00               2.94                  13.33
# 2014-12-12 06:30:00               2.80                  14.29
# 2014-12-12 07:00:00               2.71                  13.33
# 2014-12-12 07:30:00               2.67                  13.33
# 2014-12-12 08:00:00               2.65                  14.29
#
#                      avg_period_9.0_h  dominant_wave_direction_sin_9.0_h  \
# 2014-12-12 06:00:00             10.56                          -0.719340
# 2014-12-12 06:30:00             10.01                          -0.731354
# 2014-12-12 07:00:00              9.84                          -0.681998
# 2014-12-12 07:30:00              9.67                          -0.694658
# 2014-12-12 08:00:00              9.92                          -0.719340
#
#                      dominant_wave_direction_cos_9.0_h      score  wind_speed  \
# 2014-12-12 06:00:00                           0.694658   6.440000        0.60
# 2014-12-12 06:30:00                           0.681998   7.266667        0.28
# 2014-12-12 07:00:00                           0.731354   7.223333        0.20
# 2014-12-12 07:30:00                           0.719340  15.180000        0.28
# 2014-12-12 08:00:00                           0.694658   4.786667        0.52
#
#                      gust_speed  wind_direction_sin  wind_direction_cos
# 2014-12-12 06:00:00        1.05            0.410719            0.911762
# 2014-12-12 06:30:00        0.82            0.671721           -0.740805
# 2014-12-12 07:00:00        0.78            0.972776           -0.231748
# 2014-12-12 07:30:00        0.70            0.829038            0.559193
# 2014-12-12 08:00:00        0.90           -0.923210            0.384295
#
# [5 rows x 35 columns]

# %%
# Sanity check
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 348 entries, 2014-12-12 06:00:00 to 2022-02-05 09:00:00
# Data columns (total 35 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   wave_height                        348 non-null    float64
#  1   dominant_period                    348 non-null    float64
#  2   avg_period                         348 non-null    float64
#  3   dominant_wave_direction_sin        348 non-null    float64
#  4   dominant_wave_direction_cos        348 non-null    float64
#  5   wave_height_1.0_h                  348 non-null    float64
#  6   dominant_period_1.0_h              348 non-null    float64
#  7   avg_period_1.0_h                   348 non-null    float64
#  8   dominant_wave_direction_sin_1.0_h  348 non-null    float64
#  9   dominant_wave_direction_cos_1.0_h  348 non-null    float64
#  10  wave_height_1.5_h                  348 non-null    float64
#  11  dominant_period_1.5_h              348 non-null    float64
#  12  avg_period_1.5_h                   348 non-null    float64
#  13  dominant_wave_direction_sin_1.5_h  348 non-null    float64
#  14  dominant_wave_direction_cos_1.5_h  348 non-null    float64
#  15  wave_height_3.0_h                  348 non-null    float64
#  16  dominant_period_3.0_h              348 non-null    float64
#  17  avg_period_3.0_h                   348 non-null    float64
#  18  dominant_wave_direction_sin_3.0_h  348 non-null    float64
#  19  dominant_wave_direction_cos_3.0_h  348 non-null    float64
#  20  wave_height_6.0_h                  348 non-null    float64
#  21  dominant_period_6.0_h              348 non-null    float64
#  22  avg_period_6.0_h                   348 non-null    float64
#  23  dominant_wave_direction_sin_6.0_h  348 non-null    float64
#  24  dominant_wave_direction_cos_6.0_h  348 non-null    float64
#  25  wave_height_9.0_h                  348 non-null    float64
#  26  dominant_period_9.0_h              348 non-null    float64
#  27  avg_period_9.0_h                   348 non-null    float64
#  28  dominant_wave_direction_sin_9.0_h  348 non-null    float64
#  29  dominant_wave_direction_cos_9.0_h  348 non-null    float64
#  30  score                              348 non-null    float64
#  31  wind_speed                         348 non-null    float64
#  32  gust_speed                         348 non-null    float64
#  33  wind_direction_sin                 348 non-null    float64
#  34  wind_direction_cos                 348 non-null    float64
# dtypes: float64(35)
# memory usage: 97.9 KB

# %% [markdown]
# ## Save EDA and Modeling data

# %%
data.to_csv('../data/merged_data.csv')

# %% [markdown]
# ## Linear Model fun

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.metrics import mean_squared_error

# %%
X = data.drop(
    columns=[
        "score",
    ]
)
y = data['score']

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1331)

ss = StandardScaler()
X_train_sc = ss.fit_transform(X_train)
X_test_sc = ss.fit_transform(X_test)

linreg = LinearRegression()
linreg.fit(X_train_sc, y_train)
print(linreg.score(X_test_sc, y_test))
# Out:
# 0.026965553378852203

# %%
pd.DataFrame(linreg.coef_, X.columns).sort_values(by=0, ascending=False)
# Out:
#                                           0
# avg_period_1.0_h                   1.488327
# wave_height_1.5_h                  0.826082
# dominant_wave_direction_cos        0.766997
# dominant_wave_direction_sin_6.0_h  0.707394
# avg_period_9.0_h                   0.685031
# wave_height                        0.505124
# wave_height_6.0_h                  0.465903
# wind_direction_cos                 0.360936
# dominant_wave_direction_cos_3.0_h  0.344531
# dominant_period                    0.208909
# dominant_wave_direction_sin_1.0_h  0.145128
# wind_direction_sin                 0.132228
# gust_speed                         0.126514
# dominant_wave_direction_sin_1.5_h  0.121756
# avg_period_6.0_h                   0.109579
# avg_period_3.0_h                   0.099857
# dominant_period_1.0_h              0.090497
# dominant_wave_direction_cos_9.0_h  0.073732
# dominant_period_9.0_h              0.045193
# dominant_wave_direction_sin        0.030623
# dominant_wave_direction_cos_1.5_h -0.102514
# wind_speed                        -0.131864
# dominant_period_3.0_h             -0.188946
# dominant_wave_direction_sin_9.0_h -0.226273
# wave_height_9.0_h                 -0.268920
# dominant_wave_direction_cos_1.0_h -0.368940
# avg_period_1.5_h                  -0.399707
# dominant_period_1.5_h             -0.584107
# dominant_period_6.0_h             -0.621253
# dominant_wave_direction_cos_6.0_h -0.647246
# dominant_wave_direction_sin_3.0_h -0.825329
# wave_height_1.0_h                 -1.012139
# avg_period                        -1.082438
# wave_height_3.0_h                 -1.239895

# %%
mean_squared_error(y_test, linreg.predict(X_test_sc), squared=False)
# Out:
# 2.9537898032487377
