# %% [markdown]
# # EDA

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data

# %%
data = pd.read_csv('./data/merged_data.csv')
data.drop(columns='Unnamed: 0', inplace=True)
data.head()
# Out:
#    wave_height  dominant_period  avg_period  water_temp  \
# 0         2.56            11.76        9.82        25.5
# 1         2.46            13.33        9.98        25.5
# 2         2.20            12.50        9.79        25.6
# 3         2.33            11.76        9.75        25.6
# 4         2.48            11.76       10.13        25.6
#
#    dominant_wave_direction_sin  dominant_wave_direction_cos  \
# 0                    -0.681998                     0.731354
# 1                    -0.681998                     0.731354
# 2                    -0.681998                     0.731354
# 3                    -0.681998                     0.731354
# 4                    -0.529919                     0.848048
#
#    wave_height_3.0_h  dominant_period_3.0_h  avg_period_3.0_h  \
# 0               2.50                  13.33              9.83
# 1               2.69                  12.50              9.86
# 2               2.50                  13.33              9.81
# 3               2.86                  13.33             10.22
# 4               2.52                  13.33              9.60
#
#    water_temp_3.0_h  ...  dominant_period_12.0_h  avg_period_12.0_h  \
# 0              25.6  ...                   14.29               9.75
# 1              25.6  ...                   13.33               9.98
# 2              25.6  ...                   14.29               9.83
# 3              25.6  ...                   13.33               9.97
# 4              25.5  ...                   13.33              10.40
#
#    water_temp_12.0_h  dominant_wave_direction_sin_12.0_h  \
# 0               25.6                           -0.681998
# 1               25.6                           -0.719340
# 2               25.6                           -0.642788
# 3               25.6                           -0.669131
# 4               25.6                           -0.719340
#
#    dominant_wave_direction_cos_12.0_h      score  wind_speed  gust_speed  \
# 0                            0.731354   6.440000        0.60        1.05
# 1                            0.694658   7.266667        0.28        0.82
# 2                            0.766044   7.223333        0.20        0.78
# 3                            0.743145  15.180000        0.28        0.70
# 4                            0.694658   4.786667        0.52        0.90
#
#    wind_direction_sin  wind_direction_cos
# 0            0.410719            0.911762
# 1            0.671721           -0.740805
# 2            0.972776           -0.231748
# 3            0.829038            0.559193
# 4           -0.923210            0.384295
#
# [5 rows x 35 columns]

# %% [markdown]
# ## Pairplot

# %%
plt.figure(figsize=(8, 12))
sns.pairplot(
    data=data[
        [
            "wave_height",
            "dominant_period",
            "avg_period",
            "water_temp",
            "dominant_wave_direction_sin",
            "dominant_wave_direction_cos",
            "wind_speed",
            "gust_speed",
            "wind_direction_sin",
            "wind_direction_cos",
            "score",
        ]
    ],
    corner=True,
);

# %%
data.corr()['score'].sort_values()
# Out:
# dominant_period_6.0_h                -0.290794
# dominant_period_3.0_h                -0.262250
# dominant_period                      -0.235003
# dominant_period_9.0_h                -0.223908
# wave_height_3.0_h                    -0.130201
# wave_height                          -0.126441
# wind_speed                           -0.104216
# dominant_period_12.0_h               -0.079968
# gust_speed                           -0.078852
# wind_direction_cos                   -0.061781
# wave_height_6.0_h                    -0.034275
# wind_direction_sin                   -0.034194
# wave_height_12.0_h                   -0.030542
# wave_height_9.0_h                    -0.007225
# avg_period                            0.043021
# dominant_wave_direction_cos_12.0_h    0.050323
# avg_period_3.0_h                      0.061404
# dominant_wave_direction_cos_6.0_h     0.077491
# dominant_wave_direction_sin_12.0_h    0.092116
# dominant_wave_direction_cos           0.107147
# dominant_wave_direction_cos_3.0_h     0.107462
# dominant_wave_direction_cos_9.0_h     0.117964
# dominant_wave_direction_sin_3.0_h     0.123102
# dominant_wave_direction_sin_9.0_h     0.143119
# dominant_wave_direction_sin_6.0_h     0.150756
# avg_period_6.0_h                      0.159199
# dominant_wave_direction_sin           0.161917
# water_temp_3.0_h                      0.172103
# avg_period_12.0_h                     0.174619
# water_temp_6.0_h                      0.180262
# water_temp_12.0_h                     0.180670
# water_temp_9.0_h                      0.181001
# water_temp                            0.186016
# avg_period_9.0_h                      0.199619
# score                                 1.000000
# Name: score, dtype: float64

# %%
data.corr()['score'].sort_values(ascending=False)
# Out:
# score                                 1.000000
# avg_period_9.0_h                      0.199619
# water_temp                            0.186016
# water_temp_9.0_h                      0.181001
# water_temp_12.0_h                     0.180670
# water_temp_6.0_h                      0.180262
# avg_period_12.0_h                     0.174619
# water_temp_3.0_h                      0.172103
# dominant_wave_direction_sin           0.161917
# avg_period_6.0_h                      0.159199
# dominant_wave_direction_sin_6.0_h     0.150756
# dominant_wave_direction_sin_9.0_h     0.143119
# dominant_wave_direction_sin_3.0_h     0.123102
# dominant_wave_direction_cos_9.0_h     0.117964
# dominant_wave_direction_cos_3.0_h     0.107462
# dominant_wave_direction_cos           0.107147
# dominant_wave_direction_sin_12.0_h    0.092116
# dominant_wave_direction_cos_6.0_h     0.077491
# avg_period_3.0_h                      0.061404
# dominant_wave_direction_cos_12.0_h    0.050323
# avg_period                            0.043021
# wave_height_9.0_h                    -0.007225
# wave_height_12.0_h                   -0.030542
# wind_direction_sin                   -0.034194
# wave_height_6.0_h                    -0.034275
# wind_direction_cos                   -0.061781
# gust_speed                           -0.078852
# dominant_period_12.0_h               -0.079968
# wind_speed                           -0.104216
# wave_height                          -0.126441
# wave_height_3.0_h                    -0.130201
# dominant_period_9.0_h                -0.223908
# dominant_period                      -0.235003
# dominant_period_3.0_h                -0.262250
# dominant_period_6.0_h                -0.290794
# Name: score, dtype: float64
