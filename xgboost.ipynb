# %% [markdown]
# # XGBoost model

# %% [markdown]
# ## Imports

# %%
# With help from https://machinelearningmastery.com/xgboost-for-regression/

import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.model_selection import RepeatedKFold, GridSearchCV
from sklearn.metrics import mean_squared_error
from xgboost import XGBRegressor

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Data

# %%
# load the dataset
data = pd.read_csv('/content/drive/Othercomputers/My MacBook Air/Dropbox/ga/capstone/data/merged_data.csv', index_col=0)
data.head()
# Out:
#                      wave_height  dominant_period  avg_period  water_temp  \
# 2014-12-12 06:00:00         2.56            11.76        9.82        25.5
# 2014-12-12 06:30:00         2.46            13.33        9.98        25.5
# 2014-12-12 07:00:00         2.20            12.50        9.79        25.6
# 2014-12-12 07:30:00         2.33            11.76        9.75        25.6
# 2014-12-12 08:00:00         2.48            11.76       10.13        25.6
#
#                      dominant_wave_direction_sin  dominant_wave_direction_cos  \
# 2014-12-12 06:00:00                    -0.681998                     0.731354
# 2014-12-12 06:30:00                    -0.681998                     0.731354
# 2014-12-12 07:00:00                    -0.681998                     0.731354
# 2014-12-12 07:30:00                    -0.681998                     0.731354
# 2014-12-12 08:00:00                    -0.529919                     0.848048
#
#                      wave_height_3.0_h  dominant_period_3.0_h  \
# 2014-12-12 06:00:00               2.50                  13.33
# 2014-12-12 06:30:00               2.69                  12.50
# 2014-12-12 07:00:00               2.50                  13.33
# 2014-12-12 07:30:00               2.86                  13.33
# 2014-12-12 08:00:00               2.52                  13.33
#
#                      avg_period_3.0_h  water_temp_3.0_h  ...  \
# 2014-12-12 06:00:00              9.83              25.6  ...
# 2014-12-12 06:30:00              9.86              25.6  ...
# 2014-12-12 07:00:00              9.81              25.6  ...
# 2014-12-12 07:30:00             10.22              25.6  ...
# 2014-12-12 08:00:00              9.60              25.5  ...
#
#                      dominant_period_12.0_h  avg_period_12.0_h  \
# 2014-12-12 06:00:00                   14.29               9.75
# 2014-12-12 06:30:00                   13.33               9.98
# 2014-12-12 07:00:00                   14.29               9.83
# 2014-12-12 07:30:00                   13.33               9.97
# 2014-12-12 08:00:00                   13.33              10.40
#
#                      water_temp_12.0_h  dominant_wave_direction_sin_12.0_h  \
# 2014-12-12 06:00:00               25.6                           -0.681998
# 2014-12-12 06:30:00               25.6                           -0.719340
# 2014-12-12 07:00:00               25.6                           -0.642788
# 2014-12-12 07:30:00               25.6                           -0.669131
# 2014-12-12 08:00:00               25.6                           -0.719340
#
#                      dominant_wave_direction_cos_12.0_h      score  \
# 2014-12-12 06:00:00                            0.731354   6.440000
# 2014-12-12 06:30:00                            0.694658   7.266667
# 2014-12-12 07:00:00                            0.766044   7.223333
# 2014-12-12 07:30:00                            0.743145  15.180000
# 2014-12-12 08:00:00                            0.694658   4.786667
#
#                      wind_speed  gust_speed  wind_direction_sin  \
# 2014-12-12 06:00:00        0.60        1.05            0.410719
# 2014-12-12 06:30:00        0.28        0.82            0.671721
# 2014-12-12 07:00:00        0.20        0.78            0.972776
# 2014-12-12 07:30:00        0.28        0.70            0.829038
# 2014-12-12 08:00:00        0.52        0.90           -0.923210
#
#                      wind_direction_cos
# 2014-12-12 06:00:00            0.911762
# 2014-12-12 06:30:00           -0.740805
# 2014-12-12 07:00:00           -0.231748
# 2014-12-12 07:30:00            0.559193
# 2014-12-12 08:00:00            0.384295
#
# [5 rows x 35 columns]

# %% [markdown]
# ## X, y

# %%
# split data into input and output columns
X = data.drop(columns="score")
y = data["score"]

# %% [markdown]
# ## Standard Scaling

# %%
ss = StandardScaler()
X_sc = ss.fit_transform(X)

# %% [markdown]
# ## Train, test split

# %%
# train test split
X_train, X_test, y_train, y_test = train_test_split(X_sc, y, random_state=1331)

# %% [markdown]
# ## Baseline Model RSME

# %%
y_baseline_preds = np.full_like(y, y.mean()) 
mean_squared_error(y, y_baseline_preds, squared=False)
# Out:
# 3.1675113889842983

# %% [markdown]
# ## XGBoost model, no hyperparameters. KFold cross validation

# %%
# define model
model = XGBRegressor()
# define model evaluation method
cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)
# evaluate model
scores = cross_val_score(
    model, X_train, y_train, scoring="neg_root_mean_squared_error", cv=cv, n_jobs=-1
)
# force scores to be positive
scores = np.absolute(scores)
print("Mean RMSE: %.3f (%.3f)" % (scores.mean(), scores.std()))
# Out:
# Mean RMSE: 2.980 (0.421)

# %% [markdown]
# ## XGBoost model, GridSearchCV
#
# Grid search over:
# - n_estimators
# - max_depth
# - learning_rate

# %%
# define model
model = XGBRegressor(objective='reg:squarederror')

# %%
params = {
    'max_depth': [1, 3, 5],
    'n_estimators': [2_000, 5_000, 10_000],
    'learning_rate': [.1, .01, .001, .0001] 
}

# %%
gs_result = GridSearchCV(model, params, n_jobs=-1, scoring='neg_root_mean_squared_error')
gs_result.fit(X_train, y_train)
# Out:
# Best score: -2.887165790545826. Used these parameters: {'learning_rate': 0.001, 'max_depth': 1, 'n_estimators': 10000}
# -3.134372 (0.192867) with: {'learning_rate': 0.1, 'max_depth': 1, 'n_estimators': 2000}
# -3.352286 (0.234245) with: {'learning_rate': 0.1, 'max_depth': 1, 'n_estimators': 5000}
# -3.491580 (0.257461) with: {'learning_rate': 0.1, 'max_depth': 1, 'n_estimators': 10000}
# -3.159217 (0.222371) with: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 2000}
# -3.159215 (0.222370) with: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 5000}
# -3.159215 (0.222370) with: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 10000}
# -3.038870 (0.114014) with: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 2000}
# -3.038870 (0.114014) with: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 5000}
# -3.038869 (0.114013) with: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 10000}
# -2.893817 (0.127430) with: {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 2000}
# -2.934245 (0.114369) with: {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 5000}
# -3.020281 (0.132872) with: {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 10000}
# -3.010643 (0.180328) with: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 2000}
# -3.059335 (0.208052) with: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 5000}
# -3.068372 (0.210895) with: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 10000}
# -3.054136 (0.144936) with: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 2000}
# -3.059282 (0.146656) with: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 5000}
# -3.059282 (0.146654) with: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 10000}
# -3.131605 (0.353598) with: {'learning_rate': 0.001, 'max_depth': 1, 'n_estimators': 2000}
# -2.900925 (0.178293) with: {'learning_rate': 0.001, 'max_depth': 1, 'n_estimators': 5000}
# -2.887166 (0.144832) with: {'learning_rate': 0.001, 'max_depth': 1, 'n_estimators': 10000}
# -3.081989 (0.321014) with: {'learning_rate': 0.001, 'max_depth': 3, 'n_estimators': 2000}
# -2.901100 (0.162061) with: {'learning_rate': 0.001, 'max_depth': 3, 'n_estimators': 5000}
# -2.956673 (0.157278) with: {'learning_rate': 0.001, 'max_depth': 3, 'n_estimators': 10000}
# -3.152482 (0.280412) with: {'learning_rate': 0.001, 'max_depth': 5, 'n_estimators': 2000}
# -2.984521 (0.108231) with: {'learning_rate': 0.001, 'max_depth': 5, 'n_estimators': 5000}
# -3.034234 (0.117952) with: {'learning_rate': 0.001, 'max_depth': 5, 'n_estimators': 10000}
# -7.032744 (0.625180) with: {'learning_rate': 0.0001, 'max_depth': 1, 'n_estimators': 2000}
# -5.582377 (0.605370) with: {'learning_rate': 0.0001, 'max_depth': 1, 'n_estimators': 5000}
# -4.130690 (0.553787) with: {'learning_rate': 0.0001, 'max_depth': 1, 'n_estimators': 10000}
# -7.026919 (0.611209) with: {'learning_rate': 0.0001, 'max_depth': 3, 'n_estimators': 2000}
# -5.565839 (0.581312) with: {'learning_rate': 0.0001, 'max_depth': 3, 'n_estimators': 5000}
# -4.089310 (0.520347) with: {'learning_rate': 0.0001, 'max_depth': 3, 'n_estimators': 10000}
# -7.042537 (0.620359) with: {'learning_rate': 0.0001, 'max_depth': 5, 'n_estimators': 2000}
# -5.601069 (0.586385) with: {'learning_rate': 0.0001, 'max_depth': 5, 'n_estimators': 5000}
# -4.150498 (0.490625) with: {'learning_rate': 0.0001, 'max_depth': 5, 'n_estimators': 10000}

# %%
# Result summary
print(f"Best score: {np.absolute(gs_result.best_score_)}. Used these parameters: {gs_result.best_params_}")

# This part copied from machine learning mastery prints out all results to check where improvements can be made
means = np.absolute(gs_result.cv_results_['mean_test_score'])
stds = gs_result.cv_results_['std_test_score']
params = gs_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Best score: 2.887165790545826. Used these parameters: {'learning_rate': 0.001, 'max_depth': 1, 'n_estimators': 10000}
# 3.134372 (0.192867) with: {'learning_rate': 0.1, 'max_depth': 1, 'n_estimators': 2000}
# 3.352286 (0.234245) with: {'learning_rate': 0.1, 'max_depth': 1, 'n_estimators': 5000}
# 3.491580 (0.257461) with: {'learning_rate': 0.1, 'max_depth': 1, 'n_estimators': 10000}
# 3.159217 (0.222371) with: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 2000}
# 3.159215 (0.222370) with: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 5000}
# 3.159215 (0.222370) with: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 10000}
# 3.038870 (0.114014) with: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 2000}
# 3.038870 (0.114014) with: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 5000}
# 3.038869 (0.114013) with: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 10000}
# 2.893817 (0.127430) with: {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 2000}
# 2.934245 (0.114369) with: {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 5000}
# 3.020281 (0.132872) with: {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 10000}
# 3.010643 (0.180328) with: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 2000}
# 3.059335 (0.208052) with: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 5000}
# 3.068372 (0.210895) with: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 10000}
# 3.054136 (0.144936) with: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 2000}
# 3.059282 (0.146656) with: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 5000}
# 3.059282 (0.146654) with: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 10000}
# 3.131605 (0.353598) with: {'learning_rate': 0.001, 'max_depth': 1, 'n_estimators': 2000}
# 2.900925 (0.178293) with: {'learning_rate': 0.001, 'max_depth': 1, 'n_estimators': 5000}
# 2.887166 (0.144832) with: {'learning_rate': 0.001, 'max_depth': 1, 'n_estimators': 10000}
# 3.081989 (0.321014) with: {'learning_rate': 0.001, 'max_depth': 3, 'n_estimators': 2000}
# 2.901100 (0.162061) with: {'learning_rate': 0.001, 'max_depth': 3, 'n_estimators': 5000}
# 2.956673 (0.157278) with: {'learning_rate': 0.001, 'max_depth': 3, 'n_estimators': 10000}
# 3.152482 (0.280412) with: {'learning_rate': 0.001, 'max_depth': 5, 'n_estimators': 2000}
# 2.984521 (0.108231) with: {'learning_rate': 0.001, 'max_depth': 5, 'n_estimators': 5000}
# 3.034234 (0.117952) with: {'learning_rate': 0.001, 'max_depth': 5, 'n_estimators': 10000}
# 7.032744 (0.625180) with: {'learning_rate': 0.0001, 'max_depth': 1, 'n_estimators': 2000}
# 5.582377 (0.605370) with: {'learning_rate': 0.0001, 'max_depth': 1, 'n_estimators': 5000}
# 4.130690 (0.553787) with: {'learning_rate': 0.0001, 'max_depth': 1, 'n_estimators': 10000}
# 7.026919 (0.611209) with: {'learning_rate': 0.0001, 'max_depth': 3, 'n_estimators': 2000}
# 5.565839 (0.581312) with: {'learning_rate': 0.0001, 'max_depth': 3, 'n_estimators': 5000}
# 4.089310 (0.520347) with: {'learning_rate': 0.0001, 'max_depth': 3, 'n_estimators': 10000}
# 7.042537 (0.620359) with: {'learning_rate': 0.0001, 'max_depth': 5, 'n_estimators': 2000}
# 5.601069 (0.586385) with: {'learning_rate': 0.0001, 'max_depth': 5, 'n_estimators': 5000}
# 4.150498 (0.490625) with: {'learning_rate': 0.0001, 'max_depth': 5, 'n_estimators': 10000}

# %%
xgb_preds = gs_result.best_estimator_.predict(X_test)

# %%
mean_squared_error(y_test, xgb_preds)
# Out:
# 6.59736082587745
