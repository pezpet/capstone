# %% [markdown]
# # NOAA Pipeline Buoy Data

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## NOAA raw data

# %%
pd.read_csv(
    "https://www.ndbc.noaa.gov/view_text_file.php?filename=51201h2008.txt.gz&dir=data/historical/stdmet/",
    sep=" ",
    skiprows=[1]
)
# Out:
#         #YY  Unnamed: 1  MM  DD  hh   mm  WDIR  WSPD  GST  Unnamed: 9  ...  \
# 0      2008           1   1   0   0  999  99.0  99.0  NaN        2.10  ...
# 1      2008           1   1   1   0  999  99.0  99.0  NaN        2.50  ...
# 2      2008           1   1   2   0  999  99.0  99.0  NaN        2.50  ...
# 3      2008           1   1   3   0  999  99.0  99.0  NaN        2.80  ...
# 4      2008           1   1   4   0  999  99.0  99.0  NaN        2.90  ...
# ...     ...         ...  ..  ..  ..  ...   ...   ...  ...         ...  ...
# 13020  2008          12  31  21  49  999  99.0  99.0  NaN        1.67  ...
# 13021  2008          12  31  22  19  999  99.0  99.0  NaN        1.61  ...
# 13022  2008          12  31  22  49  999  99.0  99.0  NaN        1.57  ...
# 13023  2008          12  31  23  19  999  99.0  99.0  NaN        1.55  ...
# 13024  2008          12  31  23  49  999  99.0  99.0  NaN        1.68  ...
#
# ...
